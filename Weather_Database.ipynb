# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitudes and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Import citipy
from citipy import citipy

# %%
#Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
#Import the reqeusts library.
import requests

#Import the API key.
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | cap malheureux
# Processing Record 3 of Set 1 | garden city
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | kosh-agach
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | derbent
# Processing Record 10 of Set 1 | iwanai
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | arkhara
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | jijiga
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | sobolevo
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | sapele
# Processing Record 28 of Set 1 | krasnoyarskiy
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | pryyutivka
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | saint-francois
# Processing Record 33 of Set 1 | kailua
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | tuatapere
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | nanortalik
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | makakilo city
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | yulara
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | hun
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | noumea
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | biak
# Processing Record 7 of Set 2 | salalah
# Processing Record 8 of Set 2 | te anau
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | ornskoldsvik
# Processing Record 13 of Set 2 | pontes e lacerda
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | calvinia
# Processing Record 16 of Set 2 | qaqortoq
# Processing Record 17 of Set 2 | ilo
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | tucumcari
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | rio grande
# Processing Record 23 of Set 2 | chifeng
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | nioro
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | youkounkoun
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | rio gallegos
# Processing Record 32 of Set 2 | flinders
# Processing Record 33 of Set 2 | san patricio
# Processing Record 34 of Set 2 | tshikapa
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | imeni poliny osipenko
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | naze
# Processing Record 41 of Set 2 | amuntai
# Processing Record 42 of Set 2 | champerico
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | talcahuano
# Processing Record 45 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 46 of Set 2 | vestmannaeyjar
# Processing Record 47 of Set 2 | carutapera
# Processing Record 48 of Set 2 | qui nhon
# Processing Record 49 of Set 2 | ayer tawar
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | santa isabel
# Processing Record 4 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 3 | olinda
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | lagoa
# Processing Record 11 of Set 3 | charters towers
# Processing Record 12 of Set 3 | geraldton
# Processing Record 13 of Set 3 | gboko
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | moranbah
# Processing Record 16 of Set 3 | trairi
# Processing Record 17 of Set 3 | tokzar
# City not found. Skipping...
# Processing Record 18 of Set 3 | galle
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | ewo
# Processing Record 21 of Set 3 | hamilton
# Processing Record 22 of Set 3 | semey
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | ca mau
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | kalmanhaza
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 3 | limbdi
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | college
# Processing Record 36 of Set 3 | opuwo
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 3 | namibe
# Processing Record 40 of Set 3 | emirdag
# Processing Record 41 of Set 3 | nantucket
# Processing Record 42 of Set 3 | goma
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | karratha
# Processing Record 46 of Set 3 | belyy yar
# Processing Record 47 of Set 3 | simbahan
# Processing Record 48 of Set 3 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 49 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 3 | zhaoyuan
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | evensk
# Processing Record 5 of Set 4 | kanye
# Processing Record 6 of Set 4 | abnub
# Processing Record 7 of Set 4 | beringovskiy
# Processing Record 8 of Set 4 | xiangxiang
# Processing Record 9 of Set 4 | hithadhoo
# Processing Record 10 of Set 4 | usinsk
# Processing Record 11 of Set 4 | port elizabeth
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | kuppam
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | kubachi
# Processing Record 16 of Set 4 | nouadhibou
# Processing Record 17 of Set 4 | maniitsoq
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | puerto baquerizo moreno
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | la union
# Processing Record 22 of Set 4 | narsaq
# Processing Record 23 of Set 4 | imbituba
# Processing Record 24 of Set 4 | bowen
# Processing Record 25 of Set 4 | ascension
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | miri
# Processing Record 28 of Set 4 | rock springs
# Processing Record 29 of Set 4 | antofagasta
# Processing Record 30 of Set 4 | vestmanna
# Processing Record 31 of Set 4 | meaux
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | kavieng
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | lasa
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | pshekhskaya
# Processing Record 38 of Set 4 | jakarta
# Processing Record 39 of Set 4 | tessalit
# Processing Record 40 of Set 4 | praia
# Processing Record 41 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 4 | merauke
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | mulege
# Processing Record 45 of Set 4 | avarua
# Processing Record 46 of Set 4 | gouyave
# Processing Record 47 of Set 4 | tobe
# Processing Record 48 of Set 4 | sao joao dos patos
# Processing Record 49 of Set 4 | pathein
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | jiayuguan
# Processing Record 2 of Set 5 | balkhash
# Processing Record 3 of Set 5 | arlit
# Processing Record 4 of Set 5 | margate
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | imuris
# Processing Record 7 of Set 5 | mocuba
# Processing Record 8 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 5 | kaoma
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | filadelfia
# Processing Record 12 of Set 5 | tadine
# Processing Record 13 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 5 | calatayud
# Processing Record 15 of Set 5 | sembe
# Processing Record 16 of Set 5 | farafangana
# Processing Record 17 of Set 5 | san jeronimo
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | uramita
# Processing Record 21 of Set 5 | burns lake
# Processing Record 22 of Set 5 | wilmington
# Processing Record 23 of Set 5 | jian
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | montgomery
# Processing Record 26 of Set 5 | lesnikovo
# Processing Record 27 of Set 5 | basco
# Processing Record 28 of Set 5 | ponta delgada
# Processing Record 29 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 30 of Set 5 | mareeba
# Processing Record 31 of Set 5 | boma
# Processing Record 32 of Set 5 | trincomalee
# Processing Record 33 of Set 5 | sagar
# Processing Record 34 of Set 5 | malanje
# Processing Record 35 of Set 5 | kemijarvi
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | lubao
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | el alto
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | mount isa
# Processing Record 42 of Set 5 | bandarbeyla
# Processing Record 43 of Set 5 | harper
# Processing Record 44 of Set 5 | cam ranh
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | baykit
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | ignatovka
# Processing Record 49 of Set 5 | belmonte
# Processing Record 50 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 6 | henties bay
# Processing Record 2 of Set 6 | basoko
# Processing Record 3 of Set 6 | belaya gora
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | ulladulla
# Processing Record 6 of Set 6 | kavaratti
# Processing Record 7 of Set 6 | mubi
# Processing Record 8 of Set 6 | ayan
# Processing Record 9 of Set 6 | ust-nera
# Processing Record 10 of Set 6 | nalut
# Processing Record 11 of Set 6 | lebu
# Processing Record 12 of Set 6 | kuzhener
# Processing Record 13 of Set 6 | birao
# Processing Record 14 of Set 6 | east millcreek
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | chongqing
# Processing Record 18 of Set 6 | jalu
# Processing Record 19 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 6 | fort nelson
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | karasuk
# Processing Record 23 of Set 6 | atlantic city
# Processing Record 24 of Set 6 | banda aceh
# Processing Record 25 of Set 6 | turayf
# Processing Record 26 of Set 6 | masjid tanah
# Processing Record 27 of Set 6 | lorengau
# Processing Record 28 of Set 6 | calbuco
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | jizan
# Processing Record 31 of Set 6 | pangnirtung
# Processing Record 32 of Set 6 | westport
# Processing Record 33 of Set 6 | touros
# Processing Record 34 of Set 6 | florence
# Processing Record 35 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 6 | mbanza-ngungu
# Processing Record 37 of Set 6 | maroantsetra
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | okhotsk
# Processing Record 40 of Set 6 | mount gambier
# Processing Record 41 of Set 6 | izmalkovo
# Processing Record 42 of Set 6 | samfya
# Processing Record 43 of Set 6 | vila franca do campo
# Processing Record 44 of Set 6 | jiuquan
# Processing Record 45 of Set 6 | marawi
# Processing Record 46 of Set 6 | ogbomosho
# Processing Record 47 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 48 of Set 6 | ramsgate
# Processing Record 49 of Set 6 | savalou
# Processing Record 50 of Set 6 | vitim
# Processing Record 1 of Set 7 | sabha
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | tiznit
# Processing Record 4 of Set 7 | san cristobal
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | ladario
# Processing Record 7 of Set 7 | tsumeb
# Processing Record 8 of Set 7 | kokopo
# Processing Record 9 of Set 7 | kiama
# Processing Record 10 of Set 7 | jalalpur pirwala
# Processing Record 11 of Set 7 | suntar
# Processing Record 12 of Set 7 | tocopilla
# Processing Record 13 of Set 7 | north bend
# Processing Record 14 of Set 7 | impfondo
# Processing Record 15 of Set 7 | beaverlodge
# Processing Record 16 of Set 7 | steinbach
# Processing Record 17 of Set 7 | melbu
# Processing Record 18 of Set 7 | thompson
# Processing Record 19 of Set 7 | alta floresta
# Processing Record 20 of Set 7 | necochea
# Processing Record 21 of Set 7 | upernavik
# Processing Record 22 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | cairns
# Processing Record 24 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 7 | morrope
# Processing Record 26 of Set 7 | aklavik
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | uppsala
# Processing Record 29 of Set 7 | valcele
# Processing Record 30 of Set 7 | port-gentil
# Processing Record 31 of Set 7 | zemio
# Processing Record 32 of Set 7 | pemangkat
# Processing Record 33 of Set 7 | pospelikha
# Processing Record 34 of Set 7 | yar-sale
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | santiago del estero
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | el sauzal
# Processing Record 39 of Set 7 | fort thomas
# Processing Record 40 of Set 7 | venice
# Processing Record 41 of Set 7 | ewa beach
# Processing Record 42 of Set 7 | quesnel
# Processing Record 43 of Set 7 | sao mateus do sul
# Processing Record 44 of Set 7 | mamakan
# Processing Record 45 of Set 7 | sistranda
# Processing Record 46 of Set 7 | kaeo
# Processing Record 47 of Set 7 | mabaruma
# Processing Record 48 of Set 7 | moose factory
# Processing Record 49 of Set 7 | jutai
# Processing Record 50 of Set 7 | dodge city
# Processing Record 1 of Set 8 | estelle
# Processing Record 2 of Set 8 | mangai
# Processing Record 3 of Set 8 | rafaela
# Processing Record 4 of Set 8 | nuuk
# Processing Record 5 of Set 8 | atasu
# Processing Record 6 of Set 8 | bukama
# Processing Record 7 of Set 8 | keetmanshoop
# Processing Record 8 of Set 8 | san nicolas
# Processing Record 9 of Set 8 | mehran
# Processing Record 10 of Set 8 | gagarin
# Processing Record 11 of Set 8 | zhicheng
# Processing Record 12 of Set 8 | sterling
# Processing Record 13 of Set 8 | duz
# City not found. Skipping...
# Processing Record 14 of Set 8 | rosarito
# Processing Record 15 of Set 8 | mogadishu
# Processing Record 16 of Set 8 | honiara
# Processing Record 17 of Set 8 | grand-santi
# Processing Record 18 of Set 8 | okakarara
# Processing Record 19 of Set 8 | baoding
# Processing Record 20 of Set 8 | komsomolskiy
# Processing Record 21 of Set 8 | kieta
# Processing Record 22 of Set 8 | santa maria
# Processing Record 23 of Set 8 | caravelas
# Processing Record 24 of Set 8 | coihaique
# Processing Record 25 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 8 | prabumulih
# Processing Record 27 of Set 8 | adrar
# Processing Record 28 of Set 8 | esso
# Processing Record 29 of Set 8 | channel-port aux basques
# Processing Record 30 of Set 8 | tazovskiy
# Processing Record 31 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 8 | lethbridge
# Processing Record 33 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | grand gaube
# Processing Record 35 of Set 8 | neryungri
# Processing Record 36 of Set 8 | west wendover
# Processing Record 37 of Set 8 | klaksvik
# Processing Record 38 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 39 of Set 8 | asau
# Processing Record 40 of Set 8 | bayeux
# Processing Record 41 of Set 8 | privokzalnyy
# City not found. Skipping...
# Processing Record 42 of Set 8 | beloha
# Processing Record 43 of Set 8 | olafsvik
# Processing Record 44 of Set 8 | meulaboh
# Processing Record 45 of Set 8 | yilan
# Processing Record 46 of Set 8 | sinnamary
# Processing Record 47 of Set 8 | troitskoye
# Processing Record 48 of Set 8 | hovd
# Processing Record 49 of Set 8 | atar
# Processing Record 50 of Set 8 | paita
# Processing Record 1 of Set 9 | segezha
# Processing Record 2 of Set 9 | soyo
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 9 | wanlaweyn
# Processing Record 6 of Set 9 | sembakung
# Processing Record 7 of Set 9 | chapais
# Processing Record 8 of Set 9 | raga
# Processing Record 9 of Set 9 | djambala
# Processing Record 10 of Set 9 | coahuayana
# Processing Record 11 of Set 9 | leningradskiy
# Processing Record 12 of Set 9 | lesnoy
# Processing Record 13 of Set 9 | mumford
# Processing Record 14 of Set 9 | forbes
# Processing Record 15 of Set 9 | kashi
# Processing Record 16 of Set 9 | plouzane
# Processing Record 17 of Set 9 | waipawa
# Processing Record 18 of Set 9 | kenai
# Processing Record 19 of Set 9 | haines junction
# Processing Record 20 of Set 9 | arrifes
# Processing Record 21 of Set 9 | kirillov
# Processing Record 22 of Set 9 | puerto colombia
# Processing Record 23 of Set 9 | san ramon
# Processing Record 24 of Set 9 | pacific grove
# Processing Record 25 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 9 | manokwari
# Processing Record 27 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 9 | luau
# Processing Record 29 of Set 9 | simao
# Processing Record 30 of Set 9 | lawton
# Processing Record 31 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 9 | katobu
# Processing Record 33 of Set 9 | tilichiki
# Processing Record 34 of Set 9 | aripuana
# Processing Record 35 of Set 9 | dwarka
# Processing Record 36 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 9 | cherskiy
# Processing Record 38 of Set 9 | bella union
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | giyani
# Processing Record 41 of Set 9 | samarai
# Processing Record 42 of Set 9 | langsa
# Processing Record 43 of Set 9 | bandraboua
# Processing Record 44 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 9 | mandurah
# Processing Record 46 of Set 9 | chumikan
# Processing Record 47 of Set 9 | swan hill
# Processing Record 48 of Set 9 | carbondale
# Processing Record 49 of Set 9 | bud
# Processing Record 50 of Set 9 | teguldet
# Processing Record 1 of Set 10 | almelo
# Processing Record 2 of Set 10 | elk city
# Processing Record 3 of Set 10 | wajir
# Processing Record 4 of Set 10 | bunesti
# Processing Record 5 of Set 10 | sousa
# Processing Record 6 of Set 10 | najran
# Processing Record 7 of Set 10 | valparaiso
# Processing Record 8 of Set 10 | moose jaw
# Processing Record 9 of Set 10 | shimoda
# Processing Record 10 of Set 10 | buala
# Processing Record 11 of Set 10 | shelburne
# Processing Record 12 of Set 10 | cervo
# Processing Record 13 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 14 of Set 10 | mae tha
# Processing Record 15 of Set 10 | solnechnyy
# Processing Record 16 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 10 | torres
# Processing Record 18 of Set 10 | dunmore town
# Processing Record 19 of Set 10 | puerto escondido
# Processing Record 20 of Set 10 | goderich
# Processing Record 21 of Set 10 | severodvinsk
# Processing Record 22 of Set 10 | emerald
# Processing Record 23 of Set 10 | hobyo
# Processing Record 24 of Set 10 | murgab
# Processing Record 25 of Set 10 | tabalosos
# Processing Record 26 of Set 10 | lac du bonnet
# Processing Record 27 of Set 10 | licheng
# Processing Record 28 of Set 10 | nizhniy kuranakh
# Processing Record 29 of Set 10 | launceston
# Processing Record 30 of Set 10 | baruun-urt
# Processing Record 31 of Set 10 | egvekinot
# Processing Record 32 of Set 10 | vila
# Processing Record 33 of Set 10 | gat
# Processing Record 34 of Set 10 | cattolica
# Processing Record 35 of Set 10 | byron bay
# Processing Record 36 of Set 10 | kuryk
# Processing Record 37 of Set 10 | changping
# Processing Record 38 of Set 10 | port hardy
# Processing Record 39 of Set 10 | erzurum
# Processing Record 40 of Set 10 | camacha
# Processing Record 41 of Set 10 | ibiapina
# Processing Record 42 of Set 10 | samagaltay
# Processing Record 43 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 44 of Set 10 | peleduy
# Processing Record 45 of Set 10 | chute-aux-outardes
# Processing Record 46 of Set 10 | verkhnevilyuysk
# Processing Record 47 of Set 10 | at-bashi
# Processing Record 48 of Set 10 | xingcheng
# Processing Record 49 of Set 10 | kutum
# Processing Record 50 of Set 10 | tutoia
# Processing Record 1 of Set 11 | bilibino
# Processing Record 2 of Set 11 | cananeia
# Processing Record 3 of Set 11 | dembi dolo
# Processing Record 4 of Set 11 | mahanoro
# Processing Record 5 of Set 11 | kondoros
# Processing Record 6 of Set 11 | indian head
# Processing Record 7 of Set 11 | verkhoyansk
# Processing Record 8 of Set 11 | maun
# Processing Record 9 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 11 | takoradi
# Processing Record 11 of Set 11 | krasnoye
# Processing Record 12 of Set 11 | mehamn
# Processing Record 13 of Set 11 | korla
# Processing Record 14 of Set 11 | ullapool
# Processing Record 15 of Set 11 | rodrigues alves
# Processing Record 16 of Set 11 | scottsbluff
# Processing Record 17 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | ballina
# Processing Record 20 of Set 11 | santa cruz
# Processing Record 21 of Set 11 | sao joao da barra
# Processing Record 22 of Set 11 | cherdyn
# Processing Record 23 of Set 11 | haicheng
# Processing Record 24 of Set 11 | chalus
# Processing Record 25 of Set 11 | sens
# Processing Record 26 of Set 11 | skotterud
# Processing Record 27 of Set 11 | mokhsogollokh
# Processing Record 28 of Set 11 | atambua
# Processing Record 29 of Set 11 | jinchang
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | kalemie
# Processing Record 32 of Set 11 | ghansor
# Processing Record 33 of Set 11 | laguna
# Processing Record 34 of Set 11 | morant bay
# Processing Record 35 of Set 11 | svetlogorsk
# Processing Record 36 of Set 11 | alyangula
# Processing Record 37 of Set 11 | asosa
# Processing Record 38 of Set 11 | chanika
# Processing Record 39 of Set 11 | aswan
# Processing Record 40 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 11 | bay roberts
# Processing Record 42 of Set 11 | beyneu
# Processing Record 43 of Set 11 | booue
# Processing Record 44 of Set 11 | marsh harbour
# Processing Record 45 of Set 11 | kushiro
# Processing Record 46 of Set 11 | coroata
# Processing Record 47 of Set 11 | alofi
# Processing Record 48 of Set 11 | svetlyy
# Processing Record 49 of Set 11 | bobon
# Processing Record 50 of Set 11 | banjar
# Processing Record 1 of Set 12 | youghal
# Processing Record 2 of Set 12 | sao gabriel
# Processing Record 3 of Set 12 | marienburg
# Processing Record 4 of Set 12 | itaituba
# Processing Record 5 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 6 of Set 12 | chaochou
# City not found. Skipping...
# Processing Record 7 of Set 12 | zagare
# Processing Record 8 of Set 12 | wichian buri
# Processing Record 9 of Set 12 | asahikawa
# Processing Record 10 of Set 12 | tongliao
# Processing Record 11 of Set 12 | ambon
# Processing Record 12 of Set 12 | la rioja
# Processing Record 13 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 12 | sur
# Processing Record 16 of Set 12 | bayan
# Processing Record 17 of Set 12 | isangel
# Processing Record 18 of Set 12 | udachnyy
# Processing Record 19 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 12 | almeirim
# Processing Record 21 of Set 12 | mayskiy
# Processing Record 22 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 12 | krasnokamensk
# Processing Record 24 of Set 12 | hami
# Processing Record 25 of Set 12 | puerto ayacucho
# Processing Record 26 of Set 12 | esperance
# Processing Record 27 of Set 12 | saraland
# Processing Record 28 of Set 12 | rongcheng
# Processing Record 29 of Set 12 | mankono
# Processing Record 30 of Set 12 | payson
# Processing Record 31 of Set 12 | lang son
# Processing Record 32 of Set 12 | whyalla
# Processing Record 33 of Set 12 | bukachacha
# Processing Record 34 of Set 12 | amposta
# Processing Record 35 of Set 12 | ajdabiya
# Processing Record 36 of Set 12 | yining
# Processing Record 37 of Set 12 | santa rosa
# Processing Record 38 of Set 12 | saint-augustin
# Processing Record 39 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 12 | bathsheba
# Processing Record 41 of Set 12 | maldonado
# Processing Record 42 of Set 12 | catuday
# Processing Record 43 of Set 12 | port elgin
# Processing Record 44 of Set 12 | tura
# Processing Record 45 of Set 12 | cawayan
# Processing Record 46 of Set 12 | thanh hoa
# Processing Record 47 of Set 12 | bilma
# Processing Record 48 of Set 12 | bahia blanca
# Processing Record 49 of Set 12 | yerbogachen
# Processing Record 50 of Set 12 | storsteinnes
# Processing Record 1 of Set 13 | ankpa
# Processing Record 2 of Set 13 | port keats
# Processing Record 3 of Set 13 | qinzhou
# Processing Record 4 of Set 13 | harbour breton
# Processing Record 5 of Set 13 | bandundu
# Processing Record 6 of Set 13 | milkovo
# Processing Record 7 of Set 13 | veraval
# Processing Record 8 of Set 13 | minyar
# Processing Record 9 of Set 13 | darhan
# Processing Record 10 of Set 13 | ayorou
# Processing Record 11 of Set 13 | muros
# Processing Record 12 of Set 13 | mersing
# Processing Record 13 of Set 13 | guozhen
# Processing Record 14 of Set 13 | verkhnyaya inta
# Processing Record 15 of Set 13 | portland
# Processing Record 16 of Set 13 | san francisco
# Processing Record 17 of Set 13 | khani
# Processing Record 18 of Set 13 | port said
# Processing Record 19 of Set 13 | las piedras
# Processing Record 20 of Set 13 | montepuez
# Processing Record 21 of Set 13 | rocafuerte
# Processing Record 22 of Set 13 | bambanglipuro
# Processing Record 23 of Set 13 | kudahuvadhoo
# Processing Record 24 of Set 13 | oxford
# Processing Record 25 of Set 13 | sydney
# Processing Record 26 of Set 13 | antalya
# Processing Record 27 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 13 | dali
# Processing Record 29 of Set 13 | koundara
# Processing Record 30 of Set 13 | saint-joseph
# Processing Record 31 of Set 13 | horn lake
# Processing Record 32 of Set 13 | dalby
# Processing Record 33 of Set 13 | sitka
# Processing Record 34 of Set 13 | sambava
# Processing Record 35 of Set 13 | grand-lahou
# Processing Record 36 of Set 13 | murdochville
# Processing Record 37 of Set 13 | batemans bay
# Processing Record 38 of Set 13 | labuan
# Processing Record 39 of Set 13 | thinadhoo
# Processing Record 40 of Set 13 | cap-aux-meules
# Processing Record 41 of Set 13 | mantua
# Processing Record 42 of Set 13 | eucaliptus
# Processing Record 43 of Set 13 | villarrica
# Processing Record 44 of Set 13 | aguimes
# Processing Record 45 of Set 13 | manggar
# Processing Record 46 of Set 13 | camapua
# Processing Record 47 of Set 13 | valley
# Processing Record 48 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 49 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 13 | nynashamn
# Processing Record 1 of Set 14 | woodmere
# Processing Record 2 of Set 14 | srednekolymsk
# Processing Record 3 of Set 14 | berlevag
# Processing Record 4 of Set 14 | ahipara
# Processing Record 5 of Set 14 | leirvik
# Processing Record 6 of Set 14 | michigan city
# Processing Record 7 of Set 14 | zheleznodorozhnyy
# Processing Record 8 of Set 14 | torit
# Processing Record 9 of Set 14 | ishigaki
# Processing Record 10 of Set 14 | fonte boa
# Processing Record 11 of Set 14 | oksfjord
# Processing Record 12 of Set 14 | florianopolis
# Processing Record 13 of Set 14 | lesozavodsk
# Processing Record 14 of Set 14 | sao gabriel da cachoeira
# Processing Record 15 of Set 14 | avera
# Processing Record 16 of Set 14 | pitogo
# Processing Record 17 of Set 14 | riyadh
# Processing Record 18 of Set 14 | brae
# Processing Record 19 of Set 14 | khuzdar
# Processing Record 20 of Set 14 | yenangyaung
# Processing Record 21 of Set 14 | winnemucca
# Processing Record 22 of Set 14 | thaton
# Processing Record 23 of Set 14 | tigzirt
# Processing Record 24 of Set 14 | baneh
# Processing Record 25 of Set 14 | oparino
# Processing Record 26 of Set 14 | angoram
# Processing Record 27 of Set 14 | nemuro
# Processing Record 28 of Set 14 | poum
# Processing Record 29 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 30 of Set 14 | bisho
# Processing Record 31 of Set 14 | isla mujeres
# Processing Record 32 of Set 14 | moiyabana
# City not found. Skipping...
# Processing Record 33 of Set 14 | pavlovka
# Processing Record 34 of Set 14 | baghdad
# Processing Record 35 of Set 14 | fare
# Processing Record 36 of Set 14 | ye
# City not found. Skipping...
# Processing Record 37 of Set 14 | bridgetown
# Processing Record 38 of Set 14 | pechenga
# Processing Record 39 of Set 14 | matagami
# Processing Record 40 of Set 14 | biloela
# Processing Record 41 of Set 14 | campo formoso
# Processing Record 42 of Set 14 | keti bandar
# Processing Record 43 of Set 14 | tautira
# Processing Record 44 of Set 14 | san giovanni rotondo
# Processing Record 45 of Set 14 | zeya
# Processing Record 46 of Set 14 | sarkand
# Processing Record 47 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 49 of Set 14 | la ronge
# Processing Record 50 of Set 14 | powell river
# Processing Record 1 of Set 15 | rawson
# Processing Record 2 of Set 15 | merrill
# Processing Record 3 of Set 15 | changli
# Processing Record 4 of Set 15 | peniche
# Processing Record 5 of Set 15 | havre-saint-pierre
# Processing Record 6 of Set 15 | husavik
# Processing Record 7 of Set 15 | krasnyy kholm
# Processing Record 8 of Set 15 | ranau
# Processing Record 9 of Set 15 | hambantota
# Processing Record 10 of Set 15 | manta
# Processing Record 11 of Set 15 | niksic
# Processing Record 12 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 15 | fomboni
# Processing Record 14 of Set 15 | mamontovo
# Processing Record 15 of Set 15 | bury saint edmunds
# City not found. Skipping...
# Processing Record 16 of Set 15 | wana
# Processing Record 17 of Set 15 | pontianak
# Processing Record 18 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 15 | binga
# Processing Record 20 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 15 | finnsnes
# Processing Record 22 of Set 15 | buluang
# Processing Record 23 of Set 15 | yarmouth
# Processing Record 24 of Set 15 | teahupoo
# Processing Record 25 of Set 15 | wakkanai
# Processing Record 26 of Set 15 | sandviken
# Processing Record 27 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 15 | acari
# Processing Record 29 of Set 15 | maumere
# Processing Record 30 of Set 15 | faya
# Processing Record 31 of Set 15 | aromashevo
# Processing Record 32 of Set 15 | taseyevo
# Processing Record 33 of Set 15 | port hueneme
# Processing Record 34 of Set 15 | dickinson
# Processing Record 35 of Set 15 | moron
# Processing Record 36 of Set 15 | kulhudhuffushi
# Processing Record 37 of Set 15 | stjordalshalsen
# Processing Record 38 of Set 15 | kokomo
# Processing Record 39 of Set 15 | purwodadi
# Processing Record 40 of Set 15 | eufaula
# Processing Record 41 of Set 15 | tamandare
# Processing Record 42 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 15 | ugoofaaru
# Processing Record 44 of Set 15 | illapel
# Processing Record 45 of Set 15 | mudbidri
# Processing Record 46 of Set 15 | porto novo
# Processing Record 47 of Set 15 | half moon bay
# Processing Record 48 of Set 15 | sao felix do xingu
# Processing Record 49 of Set 15 | kushima

# %%
#Convert the array of dictionaries top a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona  -9.8000 -139.0333     78.03        74          29
# 1  Cap Malheureux -19.9842   57.6142     70.29        67          68
# 2     Garden City  42.3256  -83.3310     87.15        46          40
# 3    Ponta Do Sol  32.6667  -17.1000     75.70        83          31
# 4         Mataura -46.1927  168.8643     39.47        94          24
# 5      Kosh-Agach  50.0000   88.6667     49.84        81         100
# 6          Albany  42.6001  -73.9662     81.03        62          71
# 7          Hobart -42.8794  147.3294     54.05        59          20
# 8         Derbent  42.0678   48.2899     81.75        49          26
# 9          Iwanai  42.9744  140.5089     75.81        85          44
#
#    Wind Speed Country Current Description
# 0       15.73      PF    scattered clouds
# 1        5.99      MU       broken clouds
# 2       10.36      US    scattered clouds
# 3        2.28      PT    scattered clouds
# 4        1.92      NZ          few clouds
# 5        0.58      RU     overcast clouds
# 6        1.88      US       broken clouds
# 7        3.00      AU          few clouds
# 8        4.56      RU    scattered clouds
# 9        3.89      JP    scattered clouds

# %%
#Reorder the columns 
city_data_df_new_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_df_new_order]
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Atuona      PF  -9.8000 -139.0333     78.03        74
# 1        Cap Malheureux      MU -19.9842   57.6142     70.29        67
# 2           Garden City      US  42.3256  -83.3310     87.15        46
# 3          Ponta Do Sol      PT  32.6667  -17.1000     75.70        83
# 4               Mataura      NZ -46.1927  168.8643     39.47        94
# ..                  ...     ...      ...       ...       ...       ...
# 672            Mudbidri      IN  13.0833   74.9833     76.62        88
# 673          Porto Novo      BJ   6.4965    2.6036     76.17        83
# 674       Half Moon Bay      US  37.4636 -122.4286     86.54        68
# 675  Sao Felix Do Xingu      BR  -6.6447  -51.9950     88.56        25
# 676             Kushima      JP  31.4583  131.2333     78.28        87
#
#      Cloudiness  Wind Speed Current Description
# 0            29       15.73    scattered clouds
# 1            68        5.99       broken clouds
# 2            40       10.36    scattered clouds
# 3            31        2.28    scattered clouds
# 4            24        1.92          few clouds
# ..          ...         ...                 ...
# 672          75        0.00       broken clouds
# 673         100        5.68     overcast clouds
# 674           1       14.97           clear sky
# 675          41        2.82    scattered clouds
# 676          68       10.36       broken clouds
#
# [677 rows x 9 columns]

# %%
#Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database")
